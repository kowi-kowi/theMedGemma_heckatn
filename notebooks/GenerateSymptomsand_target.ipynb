# %%
import pandas as pd
import random
import json

# %%
df = pd.read_csv('core_df_with_summaries.csv')

# %%
#symtoms for random adding
SYMPTOMS_BY_TRIAGE = {
    "GREEN": [
        ["no chest pain", "no shortness of breath", "feels well"],
        ["mild chest discomfort", "anxiety"],
        ["palpitations", "fatigue"],
        ["lightheadedness", "stress"],
        ["asymptomatic", "routine checkup"]
    ],
    "YELLOW": [
        ["chest tightness", "shortness of breath on exertion"],
        ["palpitations", "dizziness"],
        ["atypical chest pain", "fatigue"],
        ["near-syncope", "weakness"],
        ["episodic chest discomfort", "nausea"]
    ],
    "RED": [
        ["severe chest pain", "shortness of breath", "diaphoresis"],
        ["crushing chest pain", "nausea", "vomiting"],
        ["syncope", "palpitations"],
        ["chest pain radiating to left arm", "shortness of breath"],
        ["confusion", "hypotension", "chest pain"]
    ]
}

# %%
def fill_synthetic_symptoms(core_df, seed=42):
    random.seed(seed)
    df = core_df.copy()

    symptoms_list = []

    for _, row in df.iterrows():
        triage = row["triage_label"]
        candidates = SYMPTOMS_BY_TRIAGE.get(triage, [["no symptoms"]])
        chosen = random.choice(candidates)
        symptoms_text = ", ".join(chosen)
        symptoms_list.append(symptoms_text)

    df["symptoms"] = symptoms_list
    return df

# %%
df = fill_synthetic_symptoms(df) #add symptoms

# %%
df.head() #check if added
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site      device  \
# 0     146     13447.0  45.0    0   182.0    90.0    NaN   3.0   CS-12   E
# 1     177     21551.0  73.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 2     223     16039.0  82.0    0     NaN     NaN    1.0   2.0       CS-12
# 3     544     13772.0  67.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 4     631      5043.0  83.0    0   183.0    70.0   11.0   1.0  AT-6     6
#
#         recording_date  ... extra_beats pacemaker strat_fold  \
# 0  1986-02-23 11:41:43  ...         NaN       NaN          7
# 1  1986-03-15 08:11:15  ...         NaN       NaN          4
# 2  1986-06-08 17:24:13  ...         NaN       NaN          9
# 3  1987-03-13 16:32:49  ...         NaN       NaN          9
# 4  1987-04-17 10:10:03  ...         1ES       NaN          4
#
#                  filename_lr                filename_hr  triage_label  \
# 0  records100/00000/00146_lr  records500/00000/00146_hr           RED
# 1  records100/00000/00177_lr  records500/00000/00177_hr           RED
# 2  records100/00000/00223_lr  records500/00000/00223_hr           RED
# 3  records100/00000/00544_lr  records500/00000/00544_hr           RED
# 4  records100/00000/00631_lr  records500/00000/00631_hr         GREEN
#
#              image_path                                        ecg_summary  \
# 0  ecg_images/00146.png  Here's a concise analysis of the 12-lead ECG:\...
# 1  ecg_images/00177.png  Here's a concise analysis of the 12-lead ECG:\...
# 2  ecg_images/00223.png  Here's a concise analysis of the provided 12-l...
# 3  ecg_images/00544.png  Here's a concise analysis of the 12-lead ECG:\...
# 4  ecg_images/00631.png  Here's a concise analysis of the provided 12-l...
#
#                                             symptoms triage_target_json
# 0  severe chest pain, shortness of breath, diapho...                NaN
# 1  severe chest pain, shortness of breath, diapho...                NaN
# 2                              syncope, palpitations                NaN
# 3              crushing chest pain, nausea, vomiting                NaN
# 4                     mild chest discomfort, anxiety                NaN
#
# [5 rows x 33 columns]

# %%
#build target

RED_FLAGS_BY_TRIAGE = {
    "GREEN": [],
    "YELLOW": [
        "ST-segment depression",
        "T-wave inversion",
        "exertional chest pain",
        "palpitations",
        "dizziness"
    ],
    "RED": [
        "ST-segment elevation",
        "ventricular ectopy",
        "tachycardia",
        "syncope",
        "severe chest pain"
    ]
}

ACTIONS_BY_TRIAGE = {
    "GREEN": [
        "Reassure patient",
        "Monitor symptoms",
        "Repeat ECG if symptoms persist",
        "Outpatient follow-up"
    ],
    "YELLOW": [
        "Repeat ECG",
        "Cardiac biomarkers",
        "Clinical observation",
        "Consider cardiology consultation"
    ],
    "RED": [
        "Urgent transfer to emergency department",
        "Continuous cardiac monitoring",
        "Repeat ECG and cardiac biomarkers",
        "Immediate cardiiology consultation"
    ]
}

# %%
def build_triage_target_json(core_df):
    df = core_df.copy()
    targets = []

    for _, row in df.iterrows():
        triage = row["triage_label"]

        target = {
            "triage_level": triage,
            "red_flags": RED_FLAGS_BY_TRIAGE.get(triage, []),
            "suggested_actions": ACTIONS_BY_TRIAGE.get(triage, [])
        }

        targets.append(json.dumps(target, indent=2))

    df["triage_target_json"] = targets
    return df

# %%
df = build_triage_target_json(df)

# %%
df.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site      device  \
# 0     146     13447.0  45.0    0   182.0    90.0    NaN   3.0   CS-12   E
# 1     177     21551.0  73.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 2     223     16039.0  82.0    0     NaN     NaN    1.0   2.0       CS-12
# 3     544     13772.0  67.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 4     631      5043.0  83.0    0   183.0    70.0   11.0   1.0  AT-6     6
#
#         recording_date  ... extra_beats pacemaker strat_fold  \
# 0  1986-02-23 11:41:43  ...         NaN       NaN          7
# 1  1986-03-15 08:11:15  ...         NaN       NaN          4
# 2  1986-06-08 17:24:13  ...         NaN       NaN          9
# 3  1987-03-13 16:32:49  ...         NaN       NaN          9
# 4  1987-04-17 10:10:03  ...         1ES       NaN          4
#
#                  filename_lr                filename_hr  triage_label  \
# 0  records100/00000/00146_lr  records500/00000/00146_hr           RED
# 1  records100/00000/00177_lr  records500/00000/00177_hr           RED
# 2  records100/00000/00223_lr  records500/00000/00223_hr           RED
# 3  records100/00000/00544_lr  records500/00000/00544_hr           RED
# 4  records100/00000/00631_lr  records500/00000/00631_hr         GREEN
#
#              image_path                                        ecg_summary  \
# 0  ecg_images/00146.png  Here's a concise analysis of the 12-lead ECG:\...
# 1  ecg_images/00177.png  Here's a concise analysis of the 12-lead ECG:\...
# 2  ecg_images/00223.png  Here's a concise analysis of the provided 12-l...
# 3  ecg_images/00544.png  Here's a concise analysis of the 12-lead ECG:\...
# 4  ecg_images/00631.png  Here's a concise analysis of the provided 12-l...
#
#                                             symptoms  \
# 0  severe chest pain, shortness of breath, diapho...
# 1  severe chest pain, shortness of breath, diapho...
# 2                              syncope, palpitations
# 3              crushing chest pain, nausea, vomiting
# 4                     mild chest discomfort, anxiety
#
#                                   triage_target_json
# 0  {\n  "triage_level": "RED",\n  "red_flags": [\...
# 1  {\n  "triage_level": "RED",\n  "red_flags": [\...
# 2  {\n  "triage_level": "RED",\n  "red_flags": [\...
# 3  {\n  "triage_level": "RED",\n  "red_flags": [\...
# 4  {\n  "triage_level": "GREEN",\n  "red_flags": ...
#
# [5 rows x 33 columns]

# %%
df.to_csv("core_db_complete.csv", index=False)
