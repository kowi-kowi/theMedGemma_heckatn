# %%
# !pip install wfdb matplotlib pandas numpy
# Out:
# Collecting wfdb
#   Using cached wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: matplotlib in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: pandas in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (1.26.4)
# Collecting aiohttp>=3.10.11 (from wfdb)
#   Using cached aiohttp-3.13.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: fsspec>=2023.10.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from wfdb) (2026.1.0)
# Requirement already satisfied: requests>=2.8.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from wfdb) (2.32.5)
# Requirement already satisfied: scipy>=1.13.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from wfdb) (1.17.0)
# Requirement already satisfied: soundfile>=0.10.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from wfdb) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from pandas) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.10.11->wfdb)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10.11->wfdb) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: six>=1.5 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (2026.1.4)
# Requirement already satisfied: cffi>=1.0 in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: pycparser in /Users/maria/projekty/medgemma_heckaton/venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Using cached wfdb-4.3.0-py3-none-any.whl (163 kB)
# Using cached aiohttp-3.13.3-cp311-cp311-macosx_10_9_x86_64.whl (499 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Installing collected packages: aiosignal, aiohttp, wfdb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [wfdb]━━━━━━ 1/3 [aiohttp]
# Successfully installed aiohttp-3.13.3 aiosignal-1.4.0 wfdb-4.3.0

# %%
import os

def record_id_to_path(base_dir, record_id, resolution="lr"):
    """
    base_dir: np. "ptb-xl/records100"
    record_id: int lub str, np. 1 albo "00001"
    resolution: "lr" or "hr"
    """
    rid = int(record_id)
    folder = f"{(rid // 1000) * 1000:05d}"
    fname = f"{rid:05d}_{resolution}"
    full_path = os.path.join(base_dir, folder, fname)
    return full_path

# %%
import wfdb

def load_ecg_signal(base_dir, record_id, resolution="lr"):
    record_path = record_id_to_path(base_dir, record_id, resolution)
    record = wfdb.rdrecord(record_path)
    signal = record.p_signal   # shape: (n_samples, 12)
    fs = record.fs             # sampling rate
    leads = record.sig_name    # nazwy odprowadzeń
    return signal, fs, leads

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_ecg_image(signal, fs, leads, out_path,
                   seconds=10, dpi=150):
    """
    signal: (n_samples, 12)
    """
    n_samples = int(seconds * fs)
    signal = signal[:n_samples]

    time = np.arange(signal.shape[0]) / fs

    fig, axes = plt.subplots(12, 1, figsize=(10, 14), sharex=True)

    for i in range(12):
        axes[i].plot(time, signal[:, i], linewidth=0.8)
        axes[i].set_ylabel(leads[i], rotation=0, labelpad=20)
        axes[i].grid(True, linestyle="--", alpha=0.3)

    axes[-1].set_xlabel("Time (s)")
    fig.suptitle("12-lead ECG", fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.savefig(out_path, dpi=dpi)
    plt.close()

# %%
def generate_ecg_png(base_dir, record_id, out_dir,
                     resolution="lr", seconds=10):
    os.makedirs(out_dir, exist_ok=True)

    signal, fs, leads = load_ecg_signal(base_dir, record_id, resolution)

    out_path = os.path.join(out_dir, f"{int(record_id):05d}.png")
    plot_ecg_image(signal, fs, leads, out_path, seconds=seconds)

    return out_path

# %%
BASE_DIR = "ecg/records100"
OUT_DIR = "ecg_images"

png_path = generate_ecg_png(
    base_dir=BASE_DIR,
    record_id=1,
    out_dir=OUT_DIR,
    resolution="lr",
    seconds=10
)

print("Saved:", png_path)
# Out:
# Saved: ecg_images/00001.png

# %%
import pandas as pd

df = pd.read_csv("ptbxl_database.csv")

# mapowanie PTB-XL → triage
def map_to_triage(scp_codes):
    scp = scp_codes.lower()
    if "mi" in scp:
        return "RED"
    if "sttc" in scp or "cd" in scp or "arr" in scp:
        return "YELLOW"
    return "GREEN"

df["triage"] = df["scp_codes"].apply(map_to_triage)

sample_df = pd.concat([
    df[df.triage=="GREEN"].sample(70, random_state=42),
    df[df.triage=="YELLOW"].sample(70, random_state=42),
    df[df.triage=="RED"].sample(60, random_state=42),
])

ids = sample_df.ecg_id.tolist()
print(len(ids))
# Out:
# 200

# %%
for id_ in ids:
    
    png_path = generate_ecg_png(
    base_dir=BASE_DIR,
    record_id=id_,
    out_dir=OUT_DIR,
    resolution="lr",
    seconds=10
    )

    print("Saved:", png_path)
# Out:
# Saved: ecg_images/02950.png
# Saved: ecg_images/21319.png
# Saved: ecg_images/02070.png
# Saved: ecg_images/21437.png
# Saved: ecg_images/16163.png
# Saved: ecg_images/08283.png
# Saved: ecg_images/02100.png
# Saved: ecg_images/14693.png
# Saved: ecg_images/10906.png
# Saved: ecg_images/02732.png
# Saved: ecg_images/19659.png
# Saved: ecg_images/11351.png
# Saved: ecg_images/13325.png
# Saved: ecg_images/20482.png
# Saved: ecg_images/17724.png
# Saved: ecg_images/19818.png
# Saved: ecg_images/00993.png
# Saved: ecg_images/11092.png
# Saved: ecg_images/12529.png
# Saved: ecg_images/20129.png
# Saved: ecg_images/14067.png
# Saved: ecg_images/07407.png
# Saved: ecg_images/04582.png
# Saved: ecg_images/04247.png
# Saved: ecg_images/03928.png
# Saved: ecg_images/10534.png
# Saved: ecg_images/04998.png
# Saved: ecg_images/01131.png
# Saved: ecg_images/03285.png
# Saved: ecg_images/16750.png
# Saved: ecg_images/08691.png
# Saved: ecg_images/20463.png
# Saved: ecg_images/21334.png
# Saved: ecg_images/08117.png
# Saved: ecg_images/06758.png
# Saved: ecg_images/02932.png
# Saved: ecg_images/07989.png
# Saved: ecg_images/17723.png
# Saved: ecg_images/14024.png
# Saved: ecg_images/12940.png
# Saved: ecg_images/03781.png
# Saved: ecg_images/08074.png
# Saved: ecg_images/04732.png
# Saved: ecg_images/07596.png
# Saved: ecg_images/07288.png
# Saved: ecg_images/14091.png
# Saved: ecg_images/20833.png
# Saved: ecg_images/10424.png
# Saved: ecg_images/17950.png
# Saved: ecg_images/12113.png
# Saved: ecg_images/00631.png
# Saved: ecg_images/16009.png
# Saved: ecg_images/03785.png
# Saved: ecg_images/01600.png
# Saved: ecg_images/17686.png
# Saved: ecg_images/12193.png
# Saved: ecg_images/14923.png
# Saved: ecg_images/19601.png
# Saved: ecg_images/05964.png
# Saved: ecg_images/18226.png
# Saved: ecg_images/10856.png
# Saved: ecg_images/11788.png
# Saved: ecg_images/07214.png
# Saved: ecg_images/05140.png
# Saved: ecg_images/21823.png
# Saved: ecg_images/03005.png
# Saved: ecg_images/13659.png
# Saved: ecg_images/17389.png
# Saved: ecg_images/01116.png
# Saved: ecg_images/21203.png
# Saved: ecg_images/05458.png
# Saved: ecg_images/02159.png
# Saved: ecg_images/20620.png
# Saved: ecg_images/15554.png
# Saved: ecg_images/17700.png
# Saved: ecg_images/09395.png
# Saved: ecg_images/15389.png
# Saved: ecg_images/06204.png
# Saved: ecg_images/02548.png
# Saved: ecg_images/06805.png
# Saved: ecg_images/21410.png
# Saved: ecg_images/01840.png
# Saved: ecg_images/18809.png
# Saved: ecg_images/09629.png
# Saved: ecg_images/11837.png
# Saved: ecg_images/19162.png
# Saved: ecg_images/20372.png
# Saved: ecg_images/00931.png
# Saved: ecg_images/05639.png
# Saved: ecg_images/05653.png
# Saved: ecg_images/02276.png
# Saved: ecg_images/02337.png
# Saved: ecg_images/16468.png
# Saved: ecg_images/01124.png
# Saved: ecg_images/11048.png
# Saved: ecg_images/15397.png
# Saved: ecg_images/21008.png
# Saved: ecg_images/16336.png
# Saved: ecg_images/17508.png
# Saved: ecg_images/05795.png
# Saved: ecg_images/07923.png
# Saved: ecg_images/11864.png
# Saved: ecg_images/05978.png
# Saved: ecg_images/17570.png
# Saved: ecg_images/12022.png
# Saved: ecg_images/01796.png
# Saved: ecg_images/18482.png
# Saved: ecg_images/16707.png
# Saved: ecg_images/14375.png
# Saved: ecg_images/20061.png
# Saved: ecg_images/06489.png
# Saved: ecg_images/16790.png
# Saved: ecg_images/21739.png
# Saved: ecg_images/09945.png
# Saved: ecg_images/14006.png
# Saved: ecg_images/15057.png
# Saved: ecg_images/16069.png
# Saved: ecg_images/20177.png
# Saved: ecg_images/02049.png
# Saved: ecg_images/21068.png
# Saved: ecg_images/04506.png
# Saved: ecg_images/10700.png
# Saved: ecg_images/09127.png
# Saved: ecg_images/06043.png
# Saved: ecg_images/01061.png
# Saved: ecg_images/07920.png
# Saved: ecg_images/11895.png
# Saved: ecg_images/01380.png
# Saved: ecg_images/19298.png
# Saved: ecg_images/07262.png
# Saved: ecg_images/04498.png
# Saved: ecg_images/07528.png
# Saved: ecg_images/14710.png
# Saved: ecg_images/15680.png
# Saved: ecg_images/10936.png
# Saved: ecg_images/12366.png
# Saved: ecg_images/13502.png
# Saved: ecg_images/17216.png
# Saved: ecg_images/04396.png
# Saved: ecg_images/08782.png
# Saved: ecg_images/02469.png
# Saved: ecg_images/06339.png
# Saved: ecg_images/11060.png
# Saved: ecg_images/19462.png
# Saved: ecg_images/21464.png
# Saved: ecg_images/04443.png
# Saved: ecg_images/11018.png
# Saved: ecg_images/18712.png
# Saved: ecg_images/19793.png
# Saved: ecg_images/03275.png
# Saved: ecg_images/09402.png
# Saved: ecg_images/10419.png
# Saved: ecg_images/01586.png
# Saved: ecg_images/10965.png
# Saved: ecg_images/19385.png
# Saved: ecg_images/13160.png
# Saved: ecg_images/15664.png
# Saved: ecg_images/19654.png
# Saved: ecg_images/00146.png
# Saved: ecg_images/16573.png
# Saved: ecg_images/21301.png
# Saved: ecg_images/04056.png
# Saved: ecg_images/09445.png
# Saved: ecg_images/08515.png
# Saved: ecg_images/01737.png
# Saved: ecg_images/02118.png
# Saved: ecg_images/05268.png
# Saved: ecg_images/18760.png
# Saved: ecg_images/14647.png
# Saved: ecg_images/12176.png
# Saved: ecg_images/07737.png
# Saved: ecg_images/16472.png
# Saved: ecg_images/00177.png
# Saved: ecg_images/12432.png
# Saved: ecg_images/08360.png
# Saved: ecg_images/08452.png
# Saved: ecg_images/14424.png
# Saved: ecg_images/20827.png
# Saved: ecg_images/10260.png
# Saved: ecg_images/15808.png
# Saved: ecg_images/06230.png
# Saved: ecg_images/04427.png
# Saved: ecg_images/11676.png
# Saved: ecg_images/16077.png
# Saved: ecg_images/00223.png
# Saved: ecg_images/16402.png
# Saved: ecg_images/18878.png
# Saved: ecg_images/19401.png
# Saved: ecg_images/16048.png
# Saved: ecg_images/15376.png
# Saved: ecg_images/02843.png
# Saved: ecg_images/10258.png
# Saved: ecg_images/13425.png
# Saved: ecg_images/02311.png
# Saved: ecg_images/15845.png
# Saved: ecg_images/00544.png
# Saved: ecg_images/17156.png
# Saved: ecg_images/18538.png
# Saved: ecg_images/09448.png
# Saved: ecg_images/20457.png

# %%
sample_df.groupby('triage').count()
# Out:
#         ecg_id  patient_id  age  sex  height  weight  nurse  site  device  \
# triage
# GREEN       70          70   70   70      25      34     64    70      70
# RED         60          60   60   60      13      14     53    60      60
# YELLOW      70          70   70   70      20      31     67    70      70
#
#         recording_date  ...  validated_by_human  baseline_drift  static_noise  \
# triage                  ...
# GREEN               70  ...                  70               2             8
# RED                 60  ...                  60               3            11
# YELLOW              70  ...                  70               3            11
#
#         burst_noise  electrodes_problems  extra_beats  pacemaker  strat_fold  \
# triage
# GREEN             3                    0            5          0          70
# RED               1                    1           11          0          60
# YELLOW            2                    0            9          0          70
#
#         filename_lr  filename_hr
# triage
# GREEN            70           70
# RED              60           60
# YELLOW           70           70
#
# [3 rows x 28 columns]

# %%
def build_core_dataset_df(sample_df, image_dir="ecg_images"):
    df = sample_df.copy()

    # ujednolicenie nazw
    df = df.rename(columns={
        "ecg_id": "ecg_id",
        "super_class": "ptbxl_superclass",
        "scp_codes": "scp_codes",
        "triage": "triage_label"
    })

    # ścieżka do obrazu (jeszcze nie istnieje fizycznie)
    df["image_path"] = df["ecg_id"].apply(
        lambda x: os.path.join(image_dir, f"{int(x):05d}.png")
    )

    # placeholdery na kolejne etapy pipeline
    df["ecg_summary"] = ""
    df["symptoms"] = ""
    df["triage_target_json"] = ""

    # sort dla powtarzalności
    df = df.sort_values("ecg_id").reset_index(drop=True)

    return df

# %%
core_df = build_core_dataset_df(sample_df, image_dir="ecg_images")

core_df.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site      device  \
# 0     146     13447.0  45.0    0   182.0    90.0    NaN   3.0   CS-12   E
# 1     177     21551.0  73.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 2     223     16039.0  82.0    0     NaN     NaN    1.0   2.0       CS-12
# 3     544     13772.0  67.0    0     NaN     NaN    NaN   3.0      AT-6 C
# 4     631      5043.0  83.0    0   183.0    70.0   11.0   1.0  AT-6     6
#
#         recording_date  ... extra_beats pacemaker strat_fold  \
# 0  1986-02-23 11:41:43  ...         NaN       NaN          7
# 1  1986-03-15 08:11:15  ...         NaN       NaN          4
# 2  1986-06-08 17:24:13  ...         NaN       NaN          9
# 3  1987-03-13 16:32:49  ...         NaN       NaN          9
# 4  1987-04-17 10:10:03  ...         1ES       NaN          4
#
#                  filename_lr                filename_hr  triage_label  \
# 0  records100/00000/00146_lr  records500/00000/00146_hr           RED
# 1  records100/00000/00177_lr  records500/00000/00177_hr           RED
# 2  records100/00000/00223_lr  records500/00000/00223_hr           RED
# 3  records100/00000/00544_lr  records500/00000/00544_hr           RED
# 4  records100/00000/00631_lr  records500/00000/00631_hr         GREEN
#
#              image_path  ecg_summary  symptoms triage_target_json
# 0  ecg_images/00146.png
# 1  ecg_images/00177.png
# 2  ecg_images/00223.png
# 3  ecg_images/00544.png
# 4  ecg_images/00631.png
#
# [5 rows x 33 columns]

# %%
core_df.to_csv("core_db.csv", index=False)
